# %%
import torch

from lafomo.data_loaders.datasets import P53Data
from lafomo.variational.models import SingleLinearLFM
from lafomo.variational.trainer import P53ConstrainedTrainer
from lafomo.options import VariationalOptions
from lafomo.utilities import save, load
from lafomo.plot.variational_plotters import Plotter

from matplotlib import pyplot as plt

# %%
dataset = P53Data(replicate=0)
num_genes = 5
num_tfs = 1
num_replicates = 1
num_times = 7

m_observed = torch.stack([
    dataset[i][1] for i in range(num_genes*num_replicates)
]).view(num_replicates, num_genes, num_times)

t_inducing = torch.linspace(0, 12, 7, dtype=torch.float64).reshape((-1, 1))
t_observed = torch.linspace(0, 12, 7).view(-1)
t_predict = torch.linspace(-1, 13, 80, dtype=torch.float64)


plt.figure(figsize=(4, 2))
plt.plot(dataset[0][1])
plt.plot(m_observed[0, 0])

# %%
options = VariationalOptions(
    preprocessing_variance=dataset.variance,
    learn_inducing=False,
    num_samples=50,
    kernel_scale=False
)

model = SingleLinearLFM(num_genes, num_tfs, t_inducing, dataset, options)
optimizer = torch.optim.Adam(model.parameters(), lr=0.05)
trainer = P53ConstrainedTrainer(model, optimizer, dataset)
plotter = Plotter(model, dataset.gene_names)
# Out:
# C:\Users\Jacob\Documents\proj\reggae\lafomo\gp\variational\models\model.py:36: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.inducing_inputs = Parameter(torch.tensor(t_inducing), requires_grad=options.learn_inducing)
# C:\Users\Jacob\Documents\proj\reggae\lafomo\gp\variational\models\model.py:53: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.initial_conditions = Parameter(torch.tensor(torch.zeros(self.num_outputs, 1)), requires_grad=True)

# %% [markdown]
# ### Outputs prior to training:

# %%
rtol = 1e-3
atol = rtol/10

model_kwargs = {
    'rtol': rtol, 'atol': atol
}

plotter.plot_kinetics()
plotter.plot_outputs(t_predict, replicate=0, t_scatter=t_observed,y_scatter=m_observed, model_kwargs=model_kwargs)
plotter.plot_latents(t_predict, ylim=(-1, 3), plot_barenco=True, plot_inducing=False)
# Out:
# C:\Users\Jacob\Documents\proj\reggae\lafomo\plot\variational_plotters.py:108: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   plt.subplot(plotnum)
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# ...
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# torch.Size([50, 5, 1])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-a7a781e3d22d> in <module>
#       7
#       8 plotter.plot_kinetics()
# ----> 9 plotter.plot_outputs(t_predict, replicate=0, t_scatter=t_observed,y_scatter=m_observed, model_kwargs=model_kwargs)
#      10 plotter.plot_latents(t_predict, ylim=(-1, 3), plot_barenco=True, plot_inducing=False)
#      11
#
# ~\Documents\proj\reggae\lafomo\plot\variational_plotters.py in plot_outputs(self, t_predict, replicate, t_scatter, y_scatter, model_kwargs, ylim)
#      33             model_kwargs: dictionary of keyword arguments to send to the model predict_m function
#      34         """
# ---> 35         mu, var = self.model.predict_m(t_predict, **model_kwargs)
#      36         mu = mu.detach()
#      37         var = 2 * torch.sqrt(var).detach()
#
# ~\Documents\proj\reggae\lafomo\gp\variational\models\model.py in predict_m(self, t_predict, **kwargs)
#     105         """
#     106         initial_value = torch.zeros((self.num_samples, self.num_outputs, 1), dtype=self.dtype)
# --> 107         outputs, var = self(t_predict.view(-1), initial_value, compute_var=True, **kwargs)
#     108         var = torch.squeeze(var).detach()
#     109         outputs = torch.squeeze(outputs).detach()
#
# ~\miniconda3\envs\wishart\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~\Documents\proj\reggae\lafomo\gp\variational\models\model.py in forward(self, t, h, rtol, atol, compute_var)
#      88         # Integrate forward from the initial positions h0.
#      89         h0 = self.initial_state(h)
# ---> 90         h_samples = odeint(self.odefunc, h0, t, method='dopri5', rtol=rtol, atol=atol)  # (T, S, num_outputs, 1)
#      91
#      92         h_out = torch.mean(h_samples, dim=1).transpose(0, 1)
#
# ~\miniconda3\envs\wishart\lib\site-packages\torchdiffeq\_impl\odeint.py in odeint(func, y0, t, rtol, atol, method, options, event_fn)
#      73
#      74     if event_fn is None:
# ---> 75         solution = solver.integrate(t)
#      76     else:
#      77         event_t, solution = solver.integrate_until_event(t[0], event_fn)
#
# ~\miniconda3\envs\wishart\lib\site-packages\torchdiffeq\_impl\solvers.py in integrate(self, t)
#      28         self._before_integrate(t)
#      29         for i in range(1, len(t)):
# ---> 30             solution[i] = self._advance(t[i])
#      31         return solution
#      32
#
# ~\miniconda3\envs\wishart\lib\site-packages\torchdiffeq\_impl\rk_common.py in _advance(self, next_t)
#     192         while next_t > self.rk_state.t1:
#     193             assert n_steps < self.max_num_steps, 'max_num_steps exceeded ({}>={})'.format(n_steps, self.max_num_steps)
# --> 194             self.rk_state = self._adaptive_step(self.rk_state)
#     195             n_steps += 1
#     196         return _interp_evaluate(self.rk_state.interp_coeff, self.rk_state.t0, self.rk_state.t1, next_t)
#
# ~\miniconda3\envs\wishart\lib\site-packages\torchdiffeq\_impl\rk_common.py in _adaptive_step(self, rk_state)
#     253         # trigger both. (i.e. interleaving them would be wrong.)
#     254
# --> 255         y1, f1, y1_error, k = _runge_kutta_step(self.func, y0, f0, t0, dt, t1, tableau=self.tableau)
#     256         # dtypes:
#     257         # y1.dtype == self.y0.dtype
#
# ~\miniconda3\envs\wishart\lib\site-packages\torchdiffeq\_impl\rk_common.py in _runge_kutta_step(func, y0, f0, t0, dt, t1, tableau)
#      74             perturb = Perturb.NONE
#      75         yi = y0 + k[..., :i + 1].matmul(beta_i * dt).view_as(f0)
# ---> 76         f = func(ti, yi, perturb=perturb)
#      77         k = _UncheckedAssign.apply(k, f, (..., i + 1))
#      78
#
# ~\miniconda3\envs\wishart\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~\miniconda3\envs\wishart\lib\site-packages\torchdiffeq\_impl\misc.py in forward(self, t, y, perturb)
#     189             # Do nothing.
#     190             pass
# --> 191         return self.base_func(t, y)
#     192
#     193
#
# ~\Documents\proj\reggae\lafomo\gp\variational\models\transcriptional.py in odefunc(self, t, h)
#      26         print(decay.shape)
#      27
# ---> 28         q_f = self.get_latents(t.reshape(-1))
#      29
#      30         # Reparameterisation trick
#
# ~\Documents\proj\reggae\lafomo\gp\variational\models\model.py in get_latents(self, t)
#     134         m_s = torch.matmul(α, self.q_m)  # (I, T*, 1)
#     135         m_s = torch.squeeze(m_s, 2)
# --> 136         Kss = self.kernel(t)  # (I, T*, T*) this is always scale=1
#     137         S_Kmm = self.S - self.Kmm  # (I, Tu, Tu)
#     138         AS_KA = torch.matmul(torch.matmul(α, S_Kmm), torch.transpose(α, 1, 2))  # (I, T*, T*)
#
# ~\miniconda3\envs\wishart\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~\Documents\proj\reggae\lafomo\gp\kernels\stationary.py in forward(self, x, x2)
#      46         sq_dist = sq_dist.repeat(self.num_outputs, 1, 1)
#      47         sq_dist = torch.div(sq_dist, 2*self.lengthscale.view((-1, 1, 1)))
# ---> 48         K = self.scale.view(-1, 1, 1) * torch.exp(-sq_dist)
#      49         if add_jitter:
#      50             jitter = 1e-5 * torch.eye(x.shape[0], dtype=K.dtype, device=K.device)
#
# ~\Documents\proj\reggae\lafomo\gp\kernels\stationary.py in scale(self)
#      23     @property
#      24     def scale(self):
# ---> 25         return softplus(self.raw_scale)
#      26
#      27     @scale.setter
#
# ~\Documents\proj\reggae\lafomo\utilities.py in softplus(value)
#      20
#      21 def softplus(value):
# ---> 22     return torch.log(1 + torch.exp(value))
#      23
#      24
#
# KeyboardInterrupt:

# %%
tol = 5e-3
import time
start = time.time()

output = trainer.train(50, rtol=tol, atol=tol/10,
                       report_interval=5, plot_interval=None)
end = time.time()
print(end - start)

# %% [markdown]
# ### Outputs after training

# %%
S = torch.tril(torch.stack(trainer.cholS).squeeze())
S = torch.matmul(S, S.transpose(1, 2))
plt.imshow(S[140])

# %%
plotter.plot_losses(trainer, last_x=100)
plotter.plot_outputs(t_predict, replicate=0, ylim=(0, 3), t_scatter=t_observed,y_scatter=m_observed, model_kwargs=model_kwargs)
plotter.plot_latents(t_predict, ylim=(-2, 4), plot_barenco=True, plot_inducing=False)
plotter.plot_kinetics()
plotter.plot_convergence(trainer)

# %%
save(model, 'variational_linear')

# %%
do_load = False
if do_load:
    model = load('variational_linear', SingleLinearLFM, num_genes, num_tfs,
                 t_inducing, dataset, extra_points=2, fixed_variance=dataset.variance)

    optimizer = torch.optim.Adam(model.parameters(), lr=0.1)
    trainer = P53ConstrainedTrainer(model, optimizer, dataset)
print(do_load)
